# %% [markdown]
# # Import everything

# %%
# works from base [Mark]
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import matplotlib.gridspec as gridspec
from mpl_toolkits.mplot3d import Axes3D
import sys
import types
import os
from pathlib import Path
try:
    import _dropbox_wrapper as dbw
except ImportError:
    dbw = None

# To run the interactive plot in cell 3, install this:
# conda install -c conda-forge ipympl ipywidgets
# %matplotlib widget
# Works in Jupyter Notebook version 7.0.8
from IPython.display import display, HTML
display(HTML("<style>.jp-Cell { margin-left: -20% !important; margin-right: -15% !important; }</style>"))
# Out:
# <style>.jp-Cell { margin-left: -20% !important; margin-right: -15% !important; }</style>

# %% [markdown]
# # Load recovery

# %%
recovery_filename = '../DATA/drum6_chirp_position1_vol_m16db_03_11_Time_09_45_50/RECOVERY.npz'
# 0) Define your placeholder function exactly as pickle expects it
def compute_CAM2_translations_v3_cupy(*args, **kwargs):
    # either a no‑op or your real implementation
    return None

# 1) Inject (or patch) the recover_core_lib module *before* loading
if 'recover_core_lib' in sys.modules:
    # if it was already imported, just add the missing name
    sys.modules['recover_core_lib'].compute_CAM2_translations_v3_cupy = compute_CAM2_translations_v3_cupy
else:
    fake = types.ModuleType('recover_core_lib')
    fake.compute_CAM2_translations_v3_cupy = compute_CAM2_translations_v3_cupy
    sys.modules['recover_core_lib'] = fake

if not os.path.isfile(recovery_filename) and dbw is not None:
    recovery_data   = np.load(dbw.dbox_read_file(Path(recovery_filename).as_posix()), allow_pickle=True)
else:
    recovery_data   = np.load(recovery_filename, allow_pickle=True)

all_shifts        = recovery_data['all_shifts']
all_params        = recovery_data['all_params']
loaded_filename   = recovery_data['loaded_filename']
run_opt           = recovery_data['run_opt'].item()

print("Recovery file loaded successfully:")
print(" - File:", recovery_filename)
print(" - all_shifts shape:", all_shifts.shape)
print(" - all_params keys:", list(all_params.keys()) if isinstance(all_params, dict) else "Not a dict")
print(" - run_opt keys:", list(run_opt.keys()) if isinstance(run_opt, dict) else "Not a dict")
print(" - fs:", run_opt['cam_params']['camera_FPS'])
all_shifts=all_shifts[:,1:]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 19
#      17     recovery_data   = np.load(dbw.dbox_read_file(Path(recovery_filename).as_posix()), allow_pickle=True)
#      18 else:
# ---> 19     recovery_data   = np.load(recovery_filename, allow_pickle=True)
#      21 all_shifts        = recovery_data['all_shifts']
#      22 all_params        = recovery_data['all_params']
#
# File ~/good-vibrations/.venv/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:451, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     449     own_fid = False
#     450 else:
# --> 451     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     452     own_fid = True
#     454 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../DATA/drum6_chirp_position1_vol_m16db_03_11_Time_09_45_50/RECOVERY.npz'

# %%
# temp hack
all_shifts=np.load('../DATA/drum3_chirp_22000Hz_vol_30_16_09_Time_16_50_03/all_shifts_rec.npy')

# %% [markdown]
# # Visualize data

# %% [markdown]
# ## Filter the signals

# %%
from scipy.signal import butter, sosfiltfilt

def bandpass_filter(data, lowcut, highcut, fs, order=5):
    sos = butter(order, [lowcut, highcut], fs=fs, btype='band', output='sos')
    return sosfiltfilt(sos, data)

lowcut = 50
highcut = 10000
fs = run_opt['cam_params']['camera_FPS']
order = 5

if 1:
    filtered_shifts = np.empty_like(all_shifts)
    for i in range(all_shifts.shape[0]):
        for j in range(all_shifts.shape[2]):
            filtered_shifts[i, :, j] = bandpass_filter(all_shifts[i, :, j], lowcut, highcut, fs, order)
else:
    filtered_shifts = all_shifts

# %% [markdown]
# ## Visualize

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider, Button
import matplotlib.gridspec as gridspec

# =============================================================================
# Dummy data for demonstration.
# Assume a 6x6 grid of sensors (36 sensors total) and a time series of 5000 samples.
# Each sensor has two signals (e.g., x and y).
# Replace this with your actual data.
n_points = 10
sensors = n_points*n_points
show_sensors = []
# all_shifts should already be defined; for example purposes, you could create dummy data:
# all_shifts = np.random.randn(sensors, 5000, 2)

# =============================================================================

show_shifts = filtered_shifts#[:36]
time_steps = all_shifts.shape[1]

# Select visualization mode: "xy_phase" or "sig_zoom"
SHOW_VIS = "xy_phase"  # Change to "sig_zoom" to run the alternative visualization
show_pnt = 0
if SHOW_VIS == "xy_phase":
    # -------------------------------
    # Mode 1: XY Phase Visualization (with additional Quiver Scale slider)
    # -------------------------------
    x_coords, y_coords = np.meshgrid(np.arange(n_points), np.arange(n_points))

    # Create a gridspec layout with 4 rows:
    # Row 0: Main plots (quiver and signal)
    # Row 1: Time slider
    # Row 2: Scale slider
    # Row 3: Step Left/Right buttons
    fig = plt.figure(figsize=(12, 10))
    gs = gridspec.GridSpec(4, 2, height_ratios=[4, 1, 1, 0.3])

    ax_quiver = fig.add_subplot(gs[0, 0])
    ax_signal = fig.add_subplot(gs[0, 1])
    ax_slider = fig.add_subplot(gs[1, :])
    ax_scale_slider = fig.add_subplot(gs[2, :])

    init_time = 0
    vectors = show_shifts[:, init_time, :].reshape(n_points, n_points, 2)
    U = vectors[:, :, 0]
    V = vectors[:, :, 1]
    # Create the initial quiver plot with a scale of 1.
    q = ax_quiver.quiver(x_coords, y_coords, U, V, pivot='tail', scale=1)
    ax_quiver.set_title(f"Surface Vibrations at Time Index {init_time}")
    ax_quiver.set_xlim(-0.5, n_points - 0.5)
    ax_quiver.set_ylim(-0.5, n_points - 0.5)
    ax_quiver.set_aspect('equal')
    ax_quiver.set_xlabel("Sensor X position")
    ax_quiver.set_ylabel("Sensor Y position")

    time_array = np.arange(time_steps)
    signal_ = show_shifts[0, :, 0]
    ax_signal.plot(time_array, signal_, lw=1)
    ax_signal.set_title("Sensor 0 X-axis Signal")
    ax_signal.set_xlabel("Time Index")
    ax_signal.set_ylabel("Amplitude")
    vline = ax_signal.axvline(init_time, color='red', lw=1.5)

    # Time slider
    slider = Slider(ax=ax_slider, label='Time Index',
                    valmin=0, valmax=time_steps - 1, valinit=init_time,
                    valfmt='%0.0f', valstep=1)

    # Quiver Scale slider
    scale_slider = Slider(ax=ax_scale_slider, label='Quiver Scale',
                          valmin=0.1, valmax=10, valinit=1, valstep=0.1)

    # Update function for time slider: update time and replot quiver with current scale.
    def update_time(val):
        global q
        t_index = int(slider.val)
        vline.set_xdata([t_index])
        vectors = show_shifts[:, t_index, :].reshape(n_points, n_points, 2)
        U = vectors[:, :, 0]
        V = vectors[:, :, 1]
        # Remove the old quiver and draw a new one with the current scale.
        q.remove()
        q = ax_quiver.quiver(x_coords, y_coords, U, V, pivot='tail', scale=scale_slider.val)
        ax_quiver.set_title(f"Surface Vibrations at Time Index {t_index}")
        fig.canvas.draw_idle()

    # Update function for scale slider: replot quiver with updated scale.
    def update_scale(val):
        global q
        t_index = int(slider.val)
        vectors = show_shifts[:, t_index, :].reshape(n_points, n_points, 2)
        U = vectors[:, :, 0]
        V = vectors[:, :, 1]
        q.remove()
        q = ax_quiver.quiver(x_coords, y_coords, U, V, pivot='tail', scale=scale_slider.val)
        fig.canvas.draw_idle()

    slider.on_changed(update_time)
    scale_slider.on_changed(update_scale)

    # Create buttons for stepping left/right.
    ax_button_left = fig.add_subplot(gs[3, 0])
    ax_button_right = fig.add_subplot(gs[3, 1])
    btn_left = Button(ax_button_left, 'Step Left')
    btn_right = Button(ax_button_right, 'Step Right')

    def step_left(event):
        current_val = int(slider.val)
        new_val = max(0, current_val - 1)
        slider.set_val(new_val)

    def step_right(event):
        current_val = int(slider.val)
        new_val = min(time_steps - 1, current_val + 1)
        slider.set_val(new_val)

    btn_left.on_clicked(step_left)
    btn_right.on_clicked(step_right)

    plt.subplots_adjust(bottom=0.25)
    plt.show()

elif SHOW_VIS == "sig_zoom":
    # -------------------------------------
    # Mode 2: Signal Zoom Visualization with Full Signal
    # (No additional buttons or scale slider)
    # -------------------------------------
    window_size = 1000
    half_window = window_size // 2

    def get_window_indices(t_index):
        start = max(0, t_index - half_window)
        end = min(time_steps, t_index + half_window)
        return start, end

    fig = plt.figure(figsize=(12, 10))
    gs = gridspec.GridSpec(4, 1, height_ratios=[1.5, 3, 3, 1])

    # Row 0: Full signal for sensor 0 x-axis.
    ax_full = fig.add_subplot(gs[0])
    time_array = np.arange(time_steps)
    ax_full.plot(time_array, filtered_shifts[show_pnt, :, 0], lw=1)
    vline_full = ax_full.axvline(0, color='red', lw=1.5)
    ax_full.set_title("Full Signal of Sensor 0 (X-axis)")
    ax_full.set_xlabel("Time Index")
    ax_full.set_ylabel("Amplitude")

    # Rows 1 and 2: Zoomed signals for all sensors.
    ax_sig_x = fig.add_subplot(gs[1])
    ax_sig_y = fig.add_subplot(gs[2])

    init_time = 0
    start, end = get_window_indices(init_time)
    time_window = np.arange(start, end)

    for sensor in range(sensors):
        ax_sig_x.plot(time_window, filtered_shifts[sensor, start:end, 0], lw=1)
        ax_sig_y.plot(time_window, filtered_shifts[sensor, start:end, 1], lw=1)

    ax_sig_x.axvline(init_time, color='red', lw=1.5)
    ax_sig_y.axvline(init_time, color='red', lw=1.5)
    ax_sig_x.set_title("X-axis Signals (Zoomed)")
    ax_sig_x.set_ylabel("Amplitude")
    ax_sig_y.set_title("Y-axis Signals (Zoomed)")
    ax_sig_y.set_xlabel("Time Index")
    ax_sig_y.set_ylabel("Amplitude")

    # Row 3: Slider.
    ax_slider = fig.add_subplot(gs[3])
    slider = Slider(ax=ax_slider, label='Time Index',
                    valmin=0, valmax=time_steps - 1, valinit=init_time,
                    valfmt='%0.0f', valstep=1)

    def update(val):
        t_index = int(slider.val)
        vline_full.set_xdata([t_index])
        start, end = get_window_indices(t_index)
        time_window = np.arange(start, end)
        ax_sig_x.cla()
        ax_sig_y.cla()
        for sensor in range(sensors):
            ax_sig_x.plot(time_window, filtered_shifts[sensor, start:end, 0], lw=1)
            ax_sig_y.plot(time_window, filtered_shifts[sensor, start:end, 1], lw=1)
        ax_sig_x.axvline(t_index, color='red', lw=1.5)
        ax_sig_y.axvline(t_index, color='red', lw=1.5)
        ax_sig_x.set_title("X-axis Signals (Zoomed)")
        ax_sig_x.set_ylabel("Amplitude")
        ax_sig_y.set_title("Y-axis Signals (Zoomed)")
        ax_sig_y.set_xlabel("Time Index")
        ax_sig_y.set_ylabel("Amplitude")
        fig.canvas.draw_idle()

    slider.on_changed(update)

    plt.subplots_adjust(hspace=0.5, bottom=0.15)
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Export video animation

# %%
from matplotlib.animation import FFMpegWriter, PillowWriter

def make_xy_phase_video(
    show_shifts: np.ndarray,
    n_points: int,
    idx_start: int,
    idx_end: int,
    fps: int = 30,
    quiver_scale: float = 1.0,
    outfile: str = "xy_phase.mp4",
    dpi: int = 150,
    signal_sensor_index: int = 0,  # which sensor to show on the right panel
    signal_component: int = 0      # 0 = x component, 1 = y component
):
    """
    Save an XY-phase quiver animation to a video.

    Parameters
    ----------
    show_shifts : np.ndarray
        Array of shape (n_points*n_points, T, 2): per-sensor (x,y) shifts over time.
        Example from your code: show_shifts = filtered_shifts / 20
    n_points : int
        Grid size (e.g., 10 -> 10x10 sensors).
    idx_start : int
        First time index to include (inclusive).
    idx_end : int
        Last time index to include (inclusive).
    fps : int
        Frames per second for the output video.
    quiver_scale : float
        Constant scale used by matplotlib's quiver (same as interactive code, but fixed).
    outfile : str
        Output filename (e.g., "xy_phase.mp4" or "xy_phase.gif").
    dpi : int
        DPI for the saved video frames.
    signal_sensor_index : int
        Which sensor's signal to plot on the right panel (0 .. n_points*n_points-1).
    signal_component : int
        Which component (0 for x, 1 for y) to plot on the right panel.
    """

    sensors, T, comps = show_shifts.shape
    assert sensors == n_points * n_points, "show_shifts first dim must be n_points*n_points"
    assert comps == 2, "show_shifts last dim must have size 2 (x,y)"

    # Clamp the requested range to valid bounds
    idx_start = max(0, idx_start)
    idx_end = min(T - 1, idx_end)
    if idx_end < idx_start:
        raise ValueError("idx_end must be >= idx_start after clamping to data length.")

    # Grid coordinates
    x_coords, y_coords = np.meshgrid(np.arange(n_points), np.arange(n_points))

    # Figure layout: left = quiver, right = one sensor's signal with a moving time cursor
    fig = plt.figure(figsize=(12, 6))
    gs = gridspec.GridSpec(1, 2, width_ratios=[1, 1.1])

    ax_quiver = fig.add_subplot(gs[0, 0])
    ax_signal = fig.add_subplot(gs[0, 1])

    # Initial frame
    t0 = idx_start
    vectors0 = show_shifts[:, t0, :].reshape(n_points, n_points, 2)
    U0 = vectors0[:, :, 0]
    V0 = vectors0[:, :, 1]

    q = ax_quiver.quiver(
        x_coords, y_coords, U0, V0,
        pivot='tail',
        scale=quiver_scale
    )
    ax_quiver.set_title(f"Surface Vibrations — Time Index {t0}")
    ax_quiver.set_xlim(-0.5, n_points - 0.5)
    ax_quiver.set_ylim(-0.5, n_points - 0.5)
    ax_quiver.set_aspect('equal')
    ax_quiver.set_xlabel("Sensor X position")
    ax_quiver.set_ylabel("Sensor Y position")

    # Right panel: show one sensor's component over the full requested time window
    time_array = np.arange(T)
    sig = show_shifts[signal_sensor_index, :, signal_component]
    ax_signal.plot(time_array, sig, lw=1)
    vline = ax_signal.axvline(t0, lw=1.5)
    comp_name = "X" if signal_component == 0 else "Y"
    ax_signal.set_title(f"Sensor {signal_sensor_index} {comp_name}-axis Signal")
    ax_signal.set_xlabel("Time Index")
    ax_signal.set_ylabel("Amplitude")
    ax_signal.set_xlim(idx_start, idx_end)

    fig.tight_layout()

    # Writer (FFmpeg preferred; fall back to Pillow if FFmpeg isn't available)
    writer = None
    if outfile.lower().endswith(".mp4"):
        try:
            writer = FFMpegWriter(fps=fps, metadata={"artist": "matplotlib"}, bitrate=1800)
        except Exception:
            raise RuntimeError(
                "FFmpeg is required to write MP4. Install FFmpeg or use a .gif outfile."
            )
    elif outfile.lower().endswith(".gif"):
        writer = PillowWriter(fps=fps)
    else:
        # default to mp4 with ffmpeg
        try:
            writer = FFMpegWriter(fps=fps, metadata={"artist": "matplotlib"}, bitrate=1800)
            if not outfile.lower().endswith(".mp4"):
                outfile = outfile + ".mp4"
        except Exception:
            writer = PillowWriter(fps=fps)
            if not outfile.lower().endswith(".gif"):
                outfile = outfile + ".gif"

    # Render frames
    with writer.saving(fig, outfile, dpi):
        for t in range(idx_start, idx_end + 1):
            # Update quiver vectors
            vectors = show_shifts[:, t, :].reshape(n_points, n_points, 2)
            U = vectors[:, :, 0]
            V = vectors[:, :, 1]
            # Update quiver in place (faster than recreating)
            q.set_UVC(U, V)

            # Update titles and time cursor
            ax_quiver.set_title(f"Surface Vibrations — Time Index {t}")
            vline.set_xdata([t])

            # Draw and capture the frame
            fig.canvas.draw()
            writer.grab_frame()

    plt.close(fig)
    print(f"Saved video to: {outfile}")


idx_start = 0
idx_end   = 4000
fps       = 60
quiver_scale = 15  # constant scale
make_xy_phase_video(show_shifts, n_points, idx_start, idx_end, fps, quiver_scale, outfile="xy_phase2.mp4")
# Out:
# Saved video to: xy_phase2.mp4

# %% [markdown]
# # Show FFTs

# %%
def plot_stacked_rfft_image(filtered_shifts, fs, use_window=True, db_scale=False,xlim = None):
    """
    filtered_shifts: np.ndarray of shape (36, 50000, 2)
    fs: sampling frequency (Hz)
    use_window: apply Hann window before FFT
    db_scale: show magnitude in dB (20*log10)
    """
    # Validate shapes
    assert filtered_shifts.ndim == 3 and filtered_shifts.shape[2] == 2, \
        "filtered_shifts must be (36, N, 2)"
    n_pts = filtered_shifts.shape[1]

    # Stack x first (dir=0) then y (dir=1) -> (72, N)
    sig_x = filtered_shifts[:, :, 0]
    sig_y = filtered_shifts[:, :, 1]
    signals = np.vstack([sig_x, sig_y])  # shape: (72, n_pts)

    # Optional window to reduce spectral leakage
    if use_window:
        window = np.hanning(n_pts)[None, :]  # broadcast across rows
        signals = signals * window

    # rFFT along time axis
    rfft_vals = np.fft.rfft(signals, axis=1)
    mag = np.abs(rfft_vals)  # shape: (72, n_freq_bins)

    # Optional dB scaling (add tiny epsilon to avoid log(0))
    if db_scale:
        mag = 20.0 * np.log10(np.maximum(mag, 1e-12))

    # Frequency axis
    freqs = np.fft.rfftfreq(n_pts, d=1.0 / fs)

    # Plot as a single image
    plt.figure(figsize=(12, 6))
    # extent: [x_min, x_max, y_min, y_max]; origin='upper' puts row 0 at top
    im = plt.imshow(
        mag,
        aspect='auto',
        origin='upper',
        extent=[freqs[0], freqs[-1], mag.shape[0] - 0.5, -0.5]
    )
    # Separator between x- and y-shift stacks
    #plt.axhline(35.5, color='white', linewidth=1)

    plt.xlabel("Frequency (Hz)")
    plt.ylabel("Signal index (0–71; 0–35 = x-shifts, 36–71 = y-shifts)")
    plt.title("Stacked rFFT Magnitude Image")
    cbar = plt.colorbar(im)
    cbar.set_label("Magnitude" + (" (dB)" if db_scale else ""))
    if xlim is not None:
        plt.xlim(xlim)
    plt.tight_layout()
    plt.show()
    return mag, freqs

# Example usage:
mags, freqs = plot_stacked_rfft_image(filtered_shifts, fs, use_window=True, db_scale=False,xlim = [0,1000])

plt.figure(figsize=(10, 3))
plt.plot(freqs,mags.std(axis=0))
plt.xlabel('Frequency [Hz]')
plt.ylabel('Mag')
plt.xlim([0,2500])
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Filter all signals around a chosen mode frequency

# %%
from scipy.signal import butter, sosfiltfilt

def heterodyne_bandpass_f0bw(data, f0, bw, fs, lpf_order=4, cutoff_frac=0.5, return_baseband=False):
    """
    Narrow-band extraction via heterodyne (mix to DC -> lowpass -> remix),
    parameterized by center frequency f0 and bandwidth bw.

    Parameters
    ----------
    data : np.ndarray
        Array with time on axis=1 (e.g., shape [I, T, J]).
    f0 : float
        Center frequency in Hz.
    bw : float
        Desired 3-dB-ish bandwidth (total width) in Hz.
    fs : float
        Sampling rate in Hz.
    lpf_order : int
        Butterworth low-pass order at baseband.
    cutoff_frac : float
        Low-pass cutoff as a fraction of (bw/2). Example: 0.5 -> cutoff = 0.5*(bw/2).
        Increase slightly (e.g., 0.7) if you want a bit wider passband.
    return_baseband : bool
        If True, return complex baseband; otherwise remix to f0 and return real bandpassed signal.

    Returns
    -------
    np.ndarray
        Complex baseband (if return_baseband) or real bandpassed signal, same shape as `data`.
    """
    if bw <= 0:
        raise ValueError("bw must be > 0")
    if f0 <= 0 or f0 >= fs/2:
        raise ValueError("f0 must be in (0, fs/2)")
    if cutoff_frac <= 0 or cutoff_frac >= 1:
        raise ValueError("cutoff_frac should be in (0, 1)")

    # For reference (not used directly): target band edges
    lowcut = f0 - bw/2
    highcut = f0 + bw/2
    if lowcut <= 0 or highcut >= fs/2:
        raise ValueError("Requested band exceeds [0, fs/2). Adjust f0/bw/fs.")

    # Time vector over axis=1
    T = data.shape[1]
    t = np.arange(T, dtype=np.float64) / fs  # shape (T,)

    # Mix down f0 -> 0 Hz
    lo_down = np.exp(-2j * np.pi * f0 * t)             # (T,)
    x_mix = data * lo_down[None, :, None]              # broadcast

    # Baseband low-pass; cutoff ~ cutoff_frac * (bw/2)
    lpf_cut = cutoff_frac * (bw / 2.0)
    if lpf_cut >= (fs / 2):
        raise ValueError("Computed LPF cutoff >= Nyquist; check fs and parameters.")

    sos = butter(lpf_order, lpf_cut, btype='low', fs=fs, output='sos')
    x_bb = sosfiltfilt(sos, x_mix, axis=1)             # complex baseband (zero-phase)

    if return_baseband:
        return x_bb

    # Remix back up to f0 and return real-valued bandpassed signal
    lo_up = np.exp(2j * np.pi * f0 * t)                # (T,)
    x_bp = np.real(x_bb * lo_up[None, :, None])
    return x_bp

# ---- Usage with your inputs ----
f0 = 2306.7 # Hz
bw = 5     # Hz (narrow)
fs = run_opt['cam_params']['camera_FPS']

# Real bandpassed signal around f0:
filtered_shifts = heterodyne_bandpass_f0bw(all_shifts, f0=f0, bw=bw, fs=fs, lpf_order=4, cutoff_frac=0.5)*10

# %% [markdown]
# # Show mode from FFT

# %%
f0       = 386.560# Hz
n_points = 10
D        = 0.01

import numpy as np

def reconstruct_surface_from_gradients(
    DX: np.ndarray,
    DY: np.ndarray,
    dx: float = 1.0,
    dy: float = 1.0,
    smoothing_lambda: float | None = None,
    smoothing_length: float | None = None,
    zero_mean: bool = True,
) -> np.ndarray:
    """
    Reconstruct a REAL surface Z[x,y] from REAL partial derivatives:
        DX = ∂Z/∂x  (axis-0),  DY = ∂Z/∂y  (axis-1),
    on a uniform grid using the Frankot–Chellappa method.

    Solves in Fourier domain (periodic BCs) the LS problem:
        minimize_Z ||DX - ∂Z/∂x||^2 + ||DY - ∂Z/∂y||^2  (+ optional Tikhonov on Z)

    Closed form:
        Ẑ(kx,ky) = ( i kx D̂X + i ky D̂Y ) / ( kx^2 + ky^2 + λ^2 )

    Parameters
    ----------
    DX, DY : (Nx, Ny) real arrays
        Spatial derivatives sampled on a rectangular, uniform grid.
        Axis-0 ↔ x, axis-1 ↔ y.
    dx, dy : float
        Grid spacings along x and y (same units as Z coordinates).
    smoothing_lambda : float or None
        Optional Tikhonov (screened Poisson) strength λ [radians per unit length].
        Larger λ ⇒ smoother Z. If None and `smoothing_length` is given, λ = 2π/ℓ.
    smoothing_length : float or None
        Convenience alternative to set λ via a physical length scale ℓ.
    zero_mean : bool
        If True, remove the mean of Z (height offset is undetermined anyway).

    Returns
    -------
    Z : (Nx, Ny) real array
        Reconstructed surface.
    """
    if DX.shape != DY.shape:
        raise ValueError("DX and DY must have the same shape (Nx, Ny).")
    if not (np.isrealobj(DX) and np.isrealobj(DY)):
        raise ValueError("DX and DY must be real arrays.")

    DX = np.asarray(DX, dtype=np.float64)
    DY = np.asarray(DY, dtype=np.float64)
    Nx, Ny = DX.shape

    # Angular spatial frequencies consistent with numpy FFTs
    kx = 2.0 * np.pi * np.fft.fftfreq(Nx, d=dx)[:, None]   # (Nx, 1)
    ky = 2.0 * np.pi * np.fft.fftfreq(Ny, d=dy)[None, :]   # (1, Ny)

    # FFT of gradients
    DX_hat = np.fft.fft2(DX)
    DY_hat = np.fft.fft2(DY)

    # Smoothing λ (screened Poisson)
    if smoothing_lambda is None:
        if smoothing_length is not None and smoothing_length > 0:
            lam = 2.0 * np.pi / float(smoothing_length)
        else:
            lam = 0.0
    else:
        lam = float(smoothing_lambda)
        if lam < 0:
            raise ValueError("smoothing_lambda must be ≥ 0")

    denom = (kx**2 + ky**2)
    if lam > 0.0:
        denom = denom + lam**2

    # Avoid division by zero at DC; numerator is 0 there for consistent gradients
    denom = denom.astype(np.float64)
    denom[0, 0] = np.inf

    # Frankot–Chellappa least-squares solution
    Z_hat = (-1j * kx * DX_hat - 1j * ky * DY_hat) / denom
    #Z_hat = (1j * kx * DX_hat + 1j * ky * DY_hat) / denom
    Z_hat[0, 0] = 0.0  # fix the arbitrary constant height

    Z = np.fft.ifft2(Z_hat).real

    if zero_mean:
        Z -= Z.mean()

    return Z


if True:
    all_shifts_FFT = np.fft.rfft(all_shifts, axis=1)
    #mag = np.abs(rfft_vals)  # shape: (72, n_freq_bins)

    fs = run_opt['cam_params']['camera_FPS']
    n_pts = all_shifts.shape[1]
    freqs = np.fft.rfftfreq(n_pts, d=1.0 / fs)
    idx_f0 = np.argmin(np.abs(freqs - f0))
    print("Closest frequency:", freqs[idx_f0], "Hz (index:", idx_f0, ")")

    FFT_f0 = all_shifts_FFT[:,idx_f0]
    FFT_f0_norm = FFT_f0 * (np.conj(FFT_f0[0,0]) / np.abs(FFT_f0[0,0]))

    x_coords, y_coords = np.meshgrid(np.arange(n_points), np.arange(n_points))
    U = np.real(FFT_f0_norm[:, 0]).reshape(n_points, n_points)
    V = np.real(FFT_f0_norm[:, 1]).reshape(n_points, n_points)

    Z = reconstruct_surface_from_gradients(U.T, V.T, dx=D, dy=D, smoothing_length=0.1,zero_mean=True)
   # Compute magnitude of all vectors (for auto quiver scaling)
    magnitudes = np.sqrt(U**2 + V**2)
    max_len = np.max(magnitudes)
    desired_frac = 0.2
    scale_auto = max_len / desired_frac

    # Coordinates for plotting (index grid and metric grid)
    X_m = x_coords * D
    Y_m = y_coords * D

    fig = plt.figure(figsize=(12, 8))

    # --- (1,2,1): Quiver of gradients (mode shape) ---
    ax1 = fig.add_subplot(1, 2, 1)
    ax1.quiver(x_coords, y_coords, U, V, scale=scale_auto)
    ax1.set_title(f"Mode shape at {f0:.2f} Hz (∂Z/∂x, ∂Z/∂y)")
    ax1.set_xlim(-0.5, n_points - 0.5)
    ax1.set_ylim(-0.5, n_points - 0.5)
    ax1.set_aspect('equal', adjustable='box')
    ax1.set_xlabel('x index')
    ax1.set_ylabel('y index')
    ax1.grid(True, linestyle='--', alpha=0.3)

    # --- (1,2,2): 3D surface of Z(x,y) ---
    ax2 = fig.add_subplot(1, 2, 2, projection='3d')
    # If you prefer millimeters, use (Z*1e3) and label accordingly.
    surf = ax2.plot_surface(X_m, Y_m, Z.T, rstride=1, cstride=1,
                            linewidth=0, antialiased=True, shade=True)
    ax2.set_title("Reconstructed Surface Z(x,y)")
    ax2.set_xlabel('x [m]')
    ax2.set_ylabel('y [m]')
    ax2.set_zlabel('Z [m]')
    # Nice viewing angle + roughly equal aspect
    ax2.view_init(elev=30, azim=-60)

    plt.tight_layout()
    plt.show()
# Out:
# Closest frequency: 386.56359819204033 Hz (index: 6185 )
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Heart beats for Srinivas

# %%
from scipy.signal import butter, sosfiltfilt

def bandpass_filter(data, lowcut, highcut, fs, order=5):
    sos = butter(order, [lowcut, highcut], fs=fs, btype='band', output='sos')
    return sosfiltfilt(sos, data)

lowcut = 0.5
highcut = 240
fs = run_opt['cam_params']['camera_FPS']
order = 5

if 1:
    filtered_shifts = np.empty_like(all_shifts)
    for i in range(all_shifts.shape[0]):
        for j in range(all_shifts.shape[2]):
            filtered_shifts[i, :, j] = bandpass_filter(all_shifts[i, :, j], lowcut, highcut, fs, order)
else:
    filtered_shifts = all_shifts

# %%
show_shifts = filtered_shifts[36:40]

num_points = show_shifts.shape[0]
time = np.arange(show_shifts.shape[1]) / fs  # time axis

fig, axes = plt.subplots(nrows=num_points, ncols=2, figsize=(15, num_points * 1.5), sharex=True)

for i in range(num_points):
    # Left column: x-axis shifts
    axes[i, 0].plot(time, show_shifts[i, :, 0], color='tab:blue')
    axes[i, 0].set_ylabel(f'Point {36+i}')
    if i == num_points - 1:
        axes[i, 0].set_xlabel('Time [s]')
    if i == 0:
        axes[i, 0].set_title('X-axis Shifts')

    # Right column: y-axis shifts
    axes[i, 1].plot(time, show_shifts[i, :, 1], color='tab:orange')
    if i == num_points - 1:
        axes[i, 1].set_xlabel('Time [s]')
    if i == 0:
        axes[i, 1].set_title('Y-axis Shifts')
#plt.xlim([0,6])
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import wave,os

def norm(sig,std_ref):
    return sig/sig.std()*std_ref

from scipy.io.wavfile import write
def save_signal_as_wav(filename, signal, sampling_rate):
    """
    Save a 1-D NumPy array as a 16-bit PCM WAV file.
    """
    sig = np.asarray(signal)
    if np.issubdtype(sig.dtype, np.floating):
        sig = sig / (np.max(np.abs(sig)) + 1e-12)  # normalize
        sig = np.int16(sig * 32767)
    write(filename, sampling_rate, sig)
    print(f"Audio file saved: {filename}")

exp_name = 'wavs_for_PPT'
audio_dir = os.path.dirname(recovery_filename) + "/"+exp_name+"/"

# ---------- Setup ----------
os.makedirs(audio_dir, exist_ok=True)

Ns,  Nt,_ = filtered_shifts.shape



# ---------- Save all signals ----------
for i in range(Ns):
    filename = f"point{i}_dx.wav"
    filepath = os.path.join(audio_dir, filename)
    save_signal_as_wav(filepath, filtered_shifts[i,:,0], fs)
    filename = f"point{i}_dy.wav"
    filepath = os.path.join(audio_dir, filename)
    save_signal_as_wav(filepath, filtered_shifts[i,:,1], fs)
# Out:
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point0_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point0_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point1_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point1_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point2_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point2_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point3_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point3_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point4_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point4_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point5_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point5_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point6_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point6_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point7_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point7_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point8_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point8_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point9_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point9_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point10_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point10_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point11_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point11_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point12_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point12_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point13_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point13_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point14_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point14_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point15_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point15_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point16_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point16_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point17_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point17_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point18_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point18_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point19_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point19_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point20_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point20_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point21_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point21_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point22_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point22_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point23_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point23_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point24_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point24_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point25_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point25_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point26_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point26_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point27_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point27_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point28_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point28_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point29_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point29_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point30_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point30_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point31_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point31_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point32_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point32_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point33_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point33_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point34_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point34_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point35_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point35_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point36_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point36_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point37_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point37_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point38_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point38_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point39_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point39_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point40_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point40_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point41_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point41_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point42_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point42_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point43_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point43_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point44_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point44_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point45_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point45_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point46_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point46_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point47_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point47_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point48_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point48_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point49_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point49_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point50_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point50_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point51_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point51_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point52_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point52_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point53_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point53_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point54_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point54_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point55_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point55_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point56_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point56_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point57_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point57_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point58_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point58_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point59_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point59_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point60_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point60_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point61_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point61_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point62_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point62_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point63_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point63_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point64_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point64_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point65_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point65_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point66_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point66_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point67_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point67_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point68_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point68_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point69_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point69_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point70_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point70_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point71_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point71_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point72_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point72_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point73_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point73_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point74_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point74_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point75_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point75_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point76_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point76_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point77_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point77_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point78_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point78_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point79_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point79_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point80_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point80_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point81_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point81_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point82_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point82_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point83_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point83_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point84_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point84_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point85_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point85_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point86_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point86_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point87_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point87_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point88_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point88_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point89_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point89_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point90_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point90_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point91_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point91_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point92_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point92_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point93_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point93_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point94_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point94_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point95_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point95_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point96_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point96_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point97_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point97_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point98_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point98_dy.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point99_dx.wav
# Audio file saved: ../DATA/chest_with_shirt_Shai_3_500Hz_15_10_Time_15_24_15/wavs_for_PPT/point99_dy.wav

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent / 'src3'))

# %%
from pathlib import Path
from vibrations_pipeline import app, process_vibrations

# .remote() requires the Modal app to be running — wrap the call in app.run()
with app.run():
    process_vibrations(Path(r"D:/eturok/experiment-22/data/samples/000432"), use_modal=True)
# Out:
# [sample 000432] upload throughput: 2595.5 MB in 4.55s = 570.4 MB/s (4563.1 Mbps)
# [sample 000432] upload raw vibrations DISK->modal_volume: 4550.83 ms
# [sample 000432] process vibrations on modal: 148776.62 ms
# [sample 000432] download processed vibrations modal_volume->DISK::D:\eturok\experiment-22\data\samples\000432: 8810.14 ms

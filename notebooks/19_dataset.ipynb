# %%
import numpy as np
from datasets import load_dataset

# %%
REPO_ID = "eturok-weizmann/laser-vibrations"

# %%
ds = load_dataset(REPO_ID, split="train")
ds
# Out:
# Dataset({
#     features: ['sample_id', 'segmented_overhead_file_name', 'speckle_vibrations_file_name', 'speckle_shifts_ifft_audio_file_name', 'audio_file_name', 'experiment_id', 'speakers', 'x_position', 'y_position', 'x_com', 'y_com', 'object', 'n_objects', 'box_material', 'mask_file_name', 'experiment_dir', 'manifest'],
#     num_rows: 551
# })

# %%
none_positions = [sample for sample in ds if sample['x_position'] is None]
none_positions
# Out:
# /Users/eitanturok/good-vibrations/.venv-vibrate/lib/python3.12/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 none_positions = [sample for sample in ds if sample['x_position'] is None]
#       2 none_positions
#
# File ~/good-vibrations/.venv-vibrate/lib/python3.12/site-packages/datasets/arrow_dataset.py:2764, in Dataset.__iter__(self)
#    2762         for i in range(pa_subtable.num_rows):
#    2763             pa_subtable_ex = pa_subtable.slice(i, 1)
# -> 2764             formatted_output = format_table(
#    2765                 pa_subtable_ex,
# ...

# %%
import sys
sys.path.insert(0, '../src')

from visualize import TrainingVisualizer

# %%
RUN_ID = "my-run-20250101-120000"  # replace with your run name

viz = TrainingVisualizer(RUN_ID)
viz.load()

# %%
viz.show(n_train=3, n_eval=3, display_mode='overlay')
